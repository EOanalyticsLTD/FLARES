# %%
import os
import sys
import glob
import cdsapi
import shutil
import datetime
import calendar
import zipfile
import numpy as np
import xarray as xr
from pathlib import Path
from datetime import timedelta

# adds the package path to the Python path to make sure all the local imports work fine 
if os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd()))) not in sys.path:
    sys.path.append(os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd()))))
    
from wp4.constants import DATA_DIR_CAMS_RE, ADS_URL, ADS_KEY, EXTENTS, POLLUTANTS

import warnings  
# Filters out a SSL warning that is given when using the cdsapi and explicitly passing the url and key as parameters 
warnings.filterwarnings("ignore", message="Unverified HTTPS request is being made to host ")

# %%
if not os.path.exists(Path(DATA_DIR_CAMS_RE).joinpath('temp')):
    os.makedirs(Path(DATA_DIR_CAMS_RE).joinpath('temp'))

# %% [markdown]
# ## Download the data from the ADS API

# %%
# initiate API client
c = cdsapi.Client(
    url=ADS_URL,
    key=ADS_KEY
)

for pollutant in POLLUTANTS:
    for year in [2018]:  # Currently only 2018 is available in the ADS
        for month in [str(x).zfill(2) for x in range(1,13)]: 

            if datetime.date(year=year, month=int(month), day=1) > datetime.date.today():
                print('Download process completed')
                break

            # get the days in the month
            days_in_month = calendar.monthrange(year, int(month))[1]

            # zero pad the days
            days_param = [str(x).zfill(2) for x in range(1, days_in_month + 1)]

            params = {
                'variable': [
                    POLLUTANTS[pollutant]['ADS_PARAM'],
                ],
                'model': 'ensemble',
                'type': 'validated_reanalysis',
                'level': '0',
                'year': year,
                'month': month,
                'format':'zip',
                'area': [x + 0.1 if ind in [0,3] else x - 0.1 for ind, x in enumerate(EXTENTS['IRELAND']['LIST'])],
            }

            # send the request to the server
            try:
                c.retrieve(
                    'cams-europe-air-quality-reanalyses',
                    params,
                    Path(DATA_DIR_CAMS_RE).joinpath(f'temp/re_{POLLUTANTS[pollutant]["CAMS"]}_{month}_{year}.zip')
                )
            except Exception as e:
                raise
# Out:
# 2021-12-13 12:38:45,005 INFO Welcome to the CDS
# 2021-12-13 12:38:45,008 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:38:45,110 INFO Request is completed
# 2021-12-13 12:38:45,113 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data8/dataset-cams-europe-air-quality-reanalyses-9a3f32cc-02b2-43a3-8209-1ec6c5897fc1.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_01_2018.zip (6.1M)
# 2021-12-13 12:38:50,401 INFO Download rate 1.2M/s
# 2021-12-13 12:38:50,478 INFO Welcome to the CDS
# 2021-12-13 12:38:50,480 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:38:50,528 INFO Request is queued
# 2021-12-13 12:38:51,565 INFO Request is running
# 2021-12-13 12:39:22,959 INFO Request is completed
# 2021-12-13 12:39:22,961 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data8/dataset-cams-europe-air-quality-reanalyses-7a91f821-bb93-45c9-8a57-b84db9dcf57d.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_02_2018.zip (5.5M)
# 2021-12-13 12:39:24,663 INFO Download rate 3.2M/s
# 2021-12-13 12:39:24,732 INFO Welcome to the CDS
# 2021-12-13 12:39:24,733 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:39:24,777 INFO Request is queued
# 2021-12-13 12:39:25,809 INFO Request is running
# 2021-12-13 12:39:38,150 INFO Request is completed
# 2021-12-13 12:39:38,154 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data8/dataset-cams-europe-air-quality-reanalyses-88d880b8-74ba-4d24-8e4e-2fb09142ec4f.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_03_2018.zip (6.2M)
# 2021-12-13 12:39:39,600 INFO Download rate 4.3M/s
# 2021-12-13 12:39:39,673 INFO Welcome to the CDS
# 2021-12-13 12:39:39,676 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:39:39,724 INFO Request is queued
# 2021-12-13 12:39:40,761 INFO Request is running
# 2021-12-13 12:39:48,243 INFO Request is completed
# 2021-12-13 12:39:48,246 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data8/dataset-cams-europe-air-quality-reanalyses-839e93c8-fa37-4de7-ac5c-ed0cd90bdc0f.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_04_2018.zip (5.9M)
# 2021-12-13 12:39:49,654 INFO Download rate 4.2M/s
# 2021-12-13 12:39:49,723 INFO Welcome to the CDS
# 2021-12-13 12:39:49,726 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:39:49,777 INFO Request is queued
# 2021-12-13 12:39:50,818 INFO Request is running
# 2021-12-13 12:39:58,065 INFO Request is completed
# 2021-12-13 12:39:58,066 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data8/dataset-cams-europe-air-quality-reanalyses-4bae78ca-2c2a-4a6f-a3e3-4b2c9b6e402f.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_05_2018.zip (6.2M)
# 2021-12-13 12:39:59,537 INFO Download rate 4.2M/s
# 2021-12-13 12:39:59,619 INFO Welcome to the CDS
# 2021-12-13 12:39:59,621 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:39:59,677 INFO Request is queued
# 2021-12-13 12:40:00,717 INFO Request is running
# 2021-12-13 12:40:32,138 INFO Request is completed
# 2021-12-13 12:40:32,139 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-85f96078-c6f2-4e19-ad0b-f7d382f1c006.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_06_2018.zip (6.2M)
# 2021-12-13 12:40:33,707 INFO Download rate 4M/s
# 2021-12-13 12:40:33,783 INFO Welcome to the CDS
# 2021-12-13 12:40:33,786 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:40:33,834 INFO Request is queued
# 2021-12-13 12:40:34,867 INFO Request is running
# 2021-12-13 12:40:42,115 INFO Request is completed
# 2021-12-13 12:40:42,118 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-7218ae73-cd6f-4aa5-91a0-3b481f1ec722.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_07_2018.zip (6.3M)
# 2021-12-13 12:40:44,180 INFO Download rate 3.1M/s
# 2021-12-13 12:40:44,263 INFO Welcome to the CDS
# 2021-12-13 12:40:44,266 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:40:44,315 INFO Request is queued
# 2021-12-13 12:40:45,351 INFO Request is running
# 2021-12-13 12:40:57,695 INFO Request is completed
# 2021-12-13 12:40:57,696 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data7/dataset-cams-europe-air-quality-reanalyses-93343ce9-fc6a-4042-89fb-521b06466232.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_08_2018.zip (6.2M)
# 2021-12-13 12:40:59,341 INFO Download rate 3.8M/s
# 2021-12-13 12:40:59,414 INFO Welcome to the CDS
# 2021-12-13 12:40:59,414 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:40:59,453 INFO Request is queued
# 2021-12-13 12:41:00,486 INFO Request is running
# 2021-12-13 12:41:07,729 INFO Request is completed
# 2021-12-13 12:41:07,734 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-a0a2cd5a-da48-44fa-8885-97416eb02835.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_09_2018.zip (5.9M)
# 2021-12-13 12:41:09,420 INFO Download rate 3.5M/s
# 2021-12-13 12:41:09,494 INFO Welcome to the CDS
# 2021-12-13 12:41:09,495 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:41:09,537 INFO Request is queued
# 2021-12-13 12:41:10,571 INFO Request is running
# 2021-12-13 12:41:22,949 INFO Request is completed
# 2021-12-13 12:41:22,950 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-86603919-c46d-45ac-a602-71f99222bdcb.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_10_2018.zip (6.3M)
# 2021-12-13 12:41:24,509 INFO Download rate 4M/s
# 2021-12-13 12:41:24,587 INFO Welcome to the CDS
# 2021-12-13 12:41:24,588 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:41:24,628 INFO Request is queued
# 2021-12-13 12:41:25,672 INFO Request is running
# 2021-12-13 12:41:32,920 INFO Request is completed
# 2021-12-13 12:41:32,921 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-a2fb4bb3-520b-4f42-a5bb-6d2d7a3d2d43.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_11_2018.zip (6.2M)
# 2021-12-13 12:41:34,445 INFO Download rate 4M/s
# 2021-12-13 12:41:34,529 INFO Welcome to the CDS
# 2021-12-13 12:41:34,531 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:41:34,570 INFO Request is queued
# 2021-12-13 12:41:35,602 INFO Request is running
# 2021-12-13 12:41:47,951 INFO Request is completed
# 2021-12-13 12:41:47,953 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-da92e79c-f11c-433d-82c2-c884e3ae0e54.zip to F:\Test_2\cams_reanalyses\temp\re_co_conc_12_2018.zip (6.2M)
# 2021-12-13 12:41:49,457 INFO Download rate 4.2M/s
# 2021-12-13 12:41:49,544 INFO Welcome to the CDS
# 2021-12-13 12:41:49,547 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:41:49,606 INFO Request is queued
# 2021-12-13 12:41:50,647 INFO Request is running
# 2021-12-13 12:41:57,890 INFO Request is completed
# 2021-12-13 12:41:57,891 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-3b0a94c0-28a1-41da-be02-32a6e931a3b8.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_01_2018.zip (6.4M)
# 2021-12-13 12:42:00,518 INFO Download rate 2.4M/s
# 2021-12-13 12:42:00,605 INFO Welcome to the CDS
# 2021-12-13 12:42:00,609 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:42:00,651 INFO Request is queued
# 2021-12-13 12:42:01,694 INFO Request is running
# 2021-12-13 12:42:09,024 INFO Request is completed
# 2021-12-13 12:42:09,029 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-40b37894-55d5-40c1-8309-2f2aa9528b31.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_02_2018.zip (5.8M)
# 2021-12-13 12:42:10,780 INFO Download rate 3.3M/s
# 2021-12-13 12:42:10,871 INFO Welcome to the CDS
# 2021-12-13 12:42:10,873 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:42:10,915 INFO Request is queued
# 2021-12-13 12:42:11,950 INFO Request is running
# 2021-12-13 12:42:19,208 INFO Request is completed
# 2021-12-13 12:42:19,210 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data8/dataset-cams-europe-air-quality-reanalyses-53b2a845-107b-4c11-9cf0-f10d59cb0c40.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_03_2018.zip (6.6M)
# 2021-12-13 12:42:20,883 INFO Download rate 3.9M/s
# 2021-12-13 12:42:20,974 INFO Welcome to the CDS
# 2021-12-13 12:42:20,978 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:42:21,028 INFO Request is queued
# 2021-12-13 12:42:22,064 INFO Request is running
# 2021-12-13 12:42:53,468 INFO Request is completed
# 2021-12-13 12:42:53,469 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data8/dataset-cams-europe-air-quality-reanalyses-a1628969-1200-4f83-b81d-4408bcfa0bda.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_04_2018.zip (6.4M)
# 2021-12-13 12:42:59,494 INFO Download rate 1.1M/s
# 2021-12-13 12:42:59,575 INFO Welcome to the CDS
# 2021-12-13 12:42:59,579 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:42:59,628 INFO Request is queued
# 2021-12-13 12:43:00,666 INFO Request is running
# 2021-12-13 12:43:07,911 INFO Request is completed
# 2021-12-13 12:43:07,913 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data7/dataset-cams-europe-air-quality-reanalyses-5e2fb7eb-cc2e-484c-b6e5-646131681a06.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_05_2018.zip (6.6M)
# 2021-12-13 12:43:09,772 INFO Download rate 3.6M/s
# 2021-12-13 12:43:09,856 INFO Welcome to the CDS
# 2021-12-13 12:43:09,857 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:43:09,894 INFO Request is queued
# 2021-12-13 12:43:10,937 INFO Request is running
# 2021-12-13 12:43:18,207 INFO Request is completed
# 2021-12-13 12:43:18,210 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-38bb9e1f-8b81-42ec-bc7b-eb7a53a2263e.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_06_2018.zip (6.4M)
# 2021-12-13 12:43:20,377 INFO Download rate 3M/s
# 2021-12-13 12:43:20,464 INFO Welcome to the CDS
# 2021-12-13 12:43:20,464 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:43:20,501 INFO Request is queued
# 2021-12-13 12:43:21,537 INFO Request is running
# 2021-12-13 12:43:28,802 INFO Request is completed
# 2021-12-13 12:43:28,806 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-8af30bd6-5ec6-4269-8718-607f894a2f39.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_07_2018.zip (6.7M)
# 2021-12-13 12:43:30,660 INFO Download rate 3.6M/s
# 2021-12-13 12:43:30,749 INFO Welcome to the CDS
# 2021-12-13 12:43:30,751 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:43:30,799 INFO Request is queued
# 2021-12-13 12:43:31,844 INFO Request is running
# 2021-12-13 12:43:39,086 INFO Request is completed
# 2021-12-13 12:43:39,088 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-c4dde737-fc2e-40e5-8dc0-e0651709226f.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_08_2018.zip (6.6M)
# 2021-12-13 12:43:41,057 INFO Download rate 3.4M/s
# 2021-12-13 12:43:41,124 INFO Welcome to the CDS
# 2021-12-13 12:43:41,125 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:43:41,170 INFO Request is queued
# 2021-12-13 12:43:42,201 INFO Request is running
# 2021-12-13 12:43:54,558 INFO Request is completed
# 2021-12-13 12:43:54,562 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-1865b811-5ccd-46c8-a2fb-9540dd9d8914.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_09_2018.zip (6.3M)
# 2021-12-13 12:43:56,097 INFO Download rate 4.1M/s
# 2021-12-13 12:43:56,181 INFO Welcome to the CDS
# 2021-12-13 12:43:56,185 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:43:56,234 INFO Request is queued
# 2021-12-13 12:43:57,270 INFO Request is running
# 2021-12-13 12:44:04,528 INFO Request is completed
# 2021-12-13 12:44:04,532 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-d939f682-7a33-45e1-bfde-ed3c76e773b6.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_10_2018.zip (6.5M)
# 2021-12-13 12:44:06,761 INFO Download rate 2.9M/s
# 2021-12-13 12:44:06,851 INFO Welcome to the CDS
# 2021-12-13 12:44:06,852 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:44:06,889 INFO Request is queued
# 2021-12-13 12:44:07,926 INFO Request is running
# 2021-12-13 12:44:15,203 INFO Request is completed
# 2021-12-13 12:44:15,204 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data3/dataset-cams-europe-air-quality-reanalyses-0564ac9e-a465-48e1-a6ae-1b64945cfd93.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_11_2018.zip (6.4M)
# 2021-12-13 12:44:16,877 INFO Download rate 3.8M/s
# 2021-12-13 12:44:16,956 INFO Welcome to the CDS
# 2021-12-13 12:44:16,957 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:44:16,995 INFO Request is queued
# 2021-12-13 12:44:18,034 INFO Request is running
# 2021-12-13 12:44:30,383 INFO Request is completed
# 2021-12-13 12:44:30,384 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data3/dataset-cams-europe-air-quality-reanalyses-49969116-567b-4014-acce-da9a870a8d7d.zip to F:\Test_2\cams_reanalyses\temp\re_o3_conc_12_2018.zip (6.5M)
# 2021-12-13 12:44:32,124 INFO Download rate 3.8M/s
# 2021-12-13 12:44:32,196 INFO Welcome to the CDS
# 2021-12-13 12:44:32,197 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:44:32,238 INFO Request is queued
# 2021-12-13 12:44:33,276 INFO Request is running
# 2021-12-13 12:44:45,613 INFO Request is completed
# 2021-12-13 12:44:45,613 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-f457de3e-4997-464e-b769-2a6339b8a1ec.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_01_2018.zip (7.3M)
# 2021-12-13 12:44:47,503 INFO Download rate 3.9M/s
# 2021-12-13 12:44:47,580 INFO Welcome to the CDS
# 2021-12-13 12:44:47,581 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:44:47,620 INFO Request is queued
# 2021-12-13 12:44:48,673 INFO Request is running
# 2021-12-13 12:45:01,030 INFO Request is completed
# 2021-12-13 12:45:01,031 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-ffddb2f0-d278-4647-8f7b-05f4c0721f80.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_02_2018.zip (6.1M)
# 2021-12-13 12:45:05,659 INFO Download rate 1.3M/s
# 2021-12-13 12:45:05,732 INFO Welcome to the CDS
# 2021-12-13 12:45:05,733 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:45:05,774 INFO Request is queued
# 2021-12-13 12:45:06,817 INFO Request is running
# 2021-12-13 12:45:26,879 INFO Request is completed
# 2021-12-13 12:45:26,882 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data1/dataset-cams-europe-air-quality-reanalyses-ce34c476-4a5d-4214-a67b-983303a247e5.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_03_2018.zip (6.3M)
# 2021-12-13 12:45:28,490 INFO Download rate 3.9M/s
# 2021-12-13 12:45:28,573 INFO Welcome to the CDS
# 2021-12-13 12:45:28,576 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:45:28,626 INFO Request is queued
# 2021-12-13 12:45:29,668 INFO Request is running
# 2021-12-13 12:45:36,915 INFO Request is completed
# 2021-12-13 12:45:36,917 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-5d023abd-6d92-4325-9d91-1b4c75604f57.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_04_2018.zip (5.5M)
# 2021-12-13 12:45:38,235 INFO Download rate 4.2M/s
# 2021-12-13 12:45:38,311 INFO Welcome to the CDS
# 2021-12-13 12:45:38,312 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:45:38,351 INFO Request is queued
# 2021-12-13 12:45:39,384 INFO Request is running
# 2021-12-13 12:45:51,730 INFO Request is completed
# 2021-12-13 12:45:51,733 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-bce1ccd2-8381-4b4a-9814-87d9ff8fba6a.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_05_2018.zip (6.5M)
# 2021-12-13 12:45:53,560 INFO Download rate 3.5M/s
# 2021-12-13 12:45:53,647 INFO Welcome to the CDS
# 2021-12-13 12:45:53,647 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:45:53,689 INFO Request is queued
# 2021-12-13 12:45:54,722 INFO Request is running
# 2021-12-13 12:46:07,071 INFO Request is completed
# 2021-12-13 12:46:07,072 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-b19450e6-5479-4c41-84d8-5c16a0a6cd1a.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_06_2018.zip (7M)
# 2021-12-13 12:46:09,194 INFO Download rate 3.3M/s
# 2021-12-13 12:46:09,323 INFO Welcome to the CDS
# 2021-12-13 12:46:09,324 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:46:09,369 INFO Request is queued
# 2021-12-13 12:46:10,403 INFO Request is running
# 2021-12-13 12:46:17,668 INFO Request is completed
# 2021-12-13 12:46:17,670 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-9b8fa32b-72b7-425d-9230-d92184586b6d.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_07_2018.zip (7.3M)
# 2021-12-13 12:46:20,256 INFO Download rate 2.8M/s
# 2021-12-13 12:46:20,343 INFO Welcome to the CDS
# 2021-12-13 12:46:20,345 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:46:20,391 INFO Request is queued
# 2021-12-13 12:46:21,428 INFO Request is running
# 2021-12-13 12:46:33,777 INFO Request is completed
# 2021-12-13 12:46:33,781 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-bb58d250-5ea9-40af-8d95-aeaa379f75f8.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_08_2018.zip (7.3M)
# 2021-12-13 12:46:36,514 INFO Download rate 2.7M/s
# 2021-12-13 12:46:36,586 INFO Welcome to the CDS
# 2021-12-13 12:46:36,587 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:46:36,622 INFO Request is queued
# 2021-12-13 12:46:37,649 INFO Request is running
# 2021-12-13 12:46:50,003 INFO Request is completed
# 2021-12-13 12:46:50,004 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-287d3810-140b-4d2a-a577-c4a2870f753d.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_09_2018.zip (7M)
# 2021-12-13 12:46:52,411 INFO Download rate 2.9M/s
# 2021-12-13 12:46:52,486 INFO Welcome to the CDS
# 2021-12-13 12:46:52,487 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:46:52,525 INFO Request is queued
# 2021-12-13 12:46:53,560 INFO Request is running
# 2021-12-13 12:47:05,917 INFO Request is completed
# 2021-12-13 12:47:05,918 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data8/dataset-cams-europe-air-quality-reanalyses-08792bbb-37bc-45ba-80ac-2acfed532dde.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_10_2018.zip (7.3M)
# 2021-12-13 12:47:08,560 INFO Download rate 2.8M/s
# 2021-12-13 12:47:08,631 INFO Welcome to the CDS
# 2021-12-13 12:47:08,632 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:47:08,677 INFO Request is queued
# 2021-12-13 12:47:09,718 INFO Request is running
# 2021-12-13 12:47:29,688 INFO Request is completed
# 2021-12-13 12:47:29,689 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data5/dataset-cams-europe-air-quality-reanalyses-0b9449af-7f9c-40af-91c3-6677135b9033.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_11_2018.zip (7M)
# 2021-12-13 12:47:32,069 INFO Download rate 3M/s
# 2021-12-13 12:47:32,164 INFO Welcome to the CDS
# 2021-12-13 12:47:32,166 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:47:32,215 INFO Request is queued
# 2021-12-13 12:47:33,250 INFO Request is running
# 2021-12-13 12:47:45,589 INFO Request is completed
# 2021-12-13 12:47:45,589 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data9/dataset-cams-europe-air-quality-reanalyses-a96458b5-8df5-44ac-ab8a-7ecd63ff5392.zip to F:\Test_2\cams_reanalyses\temp\re_no_conc_12_2018.zip (7.3M)
# 2021-12-13 12:47:47,584 INFO Download rate 3.7M/s
# 2021-12-13 12:47:47,667 INFO Welcome to the CDS
# 2021-12-13 12:47:47,668 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:47:47,710 INFO Request is queued
# 2021-12-13 12:47:49,017 INFO Request is running
# 2021-12-13 12:47:56,264 INFO Request is completed
# 2021-12-13 12:47:56,265 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-622535ff-eab0-49e7-955a-13e2a9f52dd6.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_01_2018.zip (7M)
# 2021-12-13 12:47:58,597 INFO Download rate 3M/s
# 2021-12-13 12:47:58,676 INFO Welcome to the CDS
# 2021-12-13 12:47:58,679 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:47:58,725 INFO Request is queued
# 2021-12-13 12:47:59,761 INFO Request is running
# 2021-12-13 12:48:07,017 INFO Request is completed
# 2021-12-13 12:48:07,020 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-94189ad7-4a0e-4811-a6ea-e1c538301114.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_02_2018.zip (6.3M)
# 2021-12-13 12:48:09,171 INFO Download rate 2.9M/s
# 2021-12-13 12:48:09,257 INFO Welcome to the CDS
# 2021-12-13 12:48:09,259 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:48:09,303 INFO Request is queued
# 2021-12-13 12:48:10,339 INFO Request is running
# 2021-12-13 12:48:22,699 INFO Request is completed
# 2021-12-13 12:48:22,700 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-019f3626-811e-44d7-856c-d55f11a4c635.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_03_2018.zip (7M)
# 2021-12-13 12:48:27,574 INFO Download rate 1.4M/s
# 2021-12-13 12:48:27,639 INFO Welcome to the CDS
# 2021-12-13 12:48:27,640 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:48:27,678 INFO Request is queued
# 2021-12-13 12:48:28,709 INFO Request is running
# 2021-12-13 12:48:36,007 INFO Request is completed
# 2021-12-13 12:48:36,009 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-7788eeba-d5c6-4513-82a0-8ae677e27e39.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_04_2018.zip (6.8M)
# 2021-12-13 12:48:37,781 INFO Download rate 3.8M/s
# 2021-12-13 12:48:37,862 INFO Welcome to the CDS
# 2021-12-13 12:48:37,863 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:48:37,905 INFO Request is queued
# 2021-12-13 12:48:38,940 INFO Request is running
# 2021-12-13 12:48:46,202 INFO Request is completed
# 2021-12-13 12:48:46,205 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-d1807b3b-e043-4816-85de-c7a6d9305c12.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_05_2018.zip (7M)
# 2021-12-13 12:48:48,004 INFO Download rate 3.9M/s
# 2021-12-13 12:48:48,082 INFO Welcome to the CDS
# 2021-12-13 12:48:48,086 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:48:48,137 INFO Request is queued
# 2021-12-13 12:48:49,176 INFO Request is running
# 2021-12-13 12:49:20,574 INFO Request is completed
# 2021-12-13 12:49:20,575 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-47d42e02-e4be-4e7e-8b05-b4733c4a04c7.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_06_2018.zip (6.7M)
# 2021-12-13 12:49:22,818 INFO Download rate 3M/s
# 2021-12-13 12:49:22,889 INFO Welcome to the CDS
# 2021-12-13 12:49:22,890 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:49:22,932 INFO Request is queued
# 2021-12-13 12:49:23,963 INFO Request is running
# 2021-12-13 12:49:55,361 INFO Request is completed
# 2021-12-13 12:49:55,362 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data8/dataset-cams-europe-air-quality-reanalyses-0e194e50-a398-4012-8d69-3f247739415e.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_07_2018.zip (6.9M)
# 2021-12-13 12:49:57,299 INFO Download rate 3.6M/s
# 2021-12-13 12:49:57,383 INFO Welcome to the CDS
# 2021-12-13 12:49:57,384 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:49:57,423 INFO Request is queued
# 2021-12-13 12:49:58,473 INFO Request is running
# 2021-12-13 12:50:05,698 INFO Request is completed
# 2021-12-13 12:50:05,700 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-83e07044-ebc7-4ede-a10c-14665695ca72.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_08_2018.zip (6.9M)
# 2021-12-13 12:50:07,845 INFO Download rate 3.2M/s
# 2021-12-13 12:50:07,915 INFO Welcome to the CDS
# 2021-12-13 12:50:07,915 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:50:07,954 INFO Request is queued
# 2021-12-13 12:50:08,987 INFO Request is running
# 2021-12-13 12:50:21,714 INFO Request is completed
# 2021-12-13 12:50:21,715 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-2712565a-e6ed-4b65-955c-0111b3538c92.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_09_2018.zip (6.7M)
# 2021-12-13 12:50:27,620 INFO Download rate 1.1M/s
# 2021-12-13 12:50:27,691 INFO Welcome to the CDS
# 2021-12-13 12:50:27,692 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:50:27,729 INFO Request is queued
# 2021-12-13 12:50:28,789 INFO Request is running
# 2021-12-13 12:50:41,142 INFO Request is completed
# 2021-12-13 12:50:41,143 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-8503cd76-3985-495f-9607-949b163d8107.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_10_2018.zip (7M)
# 2021-12-13 12:50:43,612 INFO Download rate 2.8M/s
# 2021-12-13 12:50:43,694 INFO Welcome to the CDS
# 2021-12-13 12:50:43,695 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:50:43,749 INFO Request is queued
# 2021-12-13 12:50:44,802 INFO Request is running
# 2021-12-13 12:50:57,154 INFO Request is completed
# 2021-12-13 12:50:57,156 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-ab529489-63a9-4adf-9e16-d6572b38e0bf.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_11_2018.zip (6.8M)
# 2021-12-13 12:51:00,749 INFO Download rate 1.9M/s
# 2021-12-13 12:51:00,823 INFO Welcome to the CDS
# 2021-12-13 12:51:00,823 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:51:00,860 INFO Request is queued
# 2021-12-13 12:51:01,891 INFO Request is running
# 2021-12-13 12:51:14,491 INFO Request is completed
# 2021-12-13 12:51:14,492 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-8f636987-d50a-416b-a07d-2a3990477cc9.zip to F:\Test_2\cams_reanalyses\temp\re_no2_conc_12_2018.zip (7.1M)
# 2021-12-13 12:51:16,332 INFO Download rate 3.9M/s
# 2021-12-13 12:51:16,410 INFO Welcome to the CDS
# 2021-12-13 12:51:16,412 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:51:16,453 INFO Request is queued
# 2021-12-13 12:51:17,482 INFO Request is running
# 2021-12-13 12:51:29,808 INFO Request is completed
# 2021-12-13 12:51:29,809 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data9/dataset-cams-europe-air-quality-reanalyses-00441ce0-ceea-44c4-a278-991d2bca9fec.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_01_2018.zip (6.7M)
# 2021-12-13 12:51:31,571 INFO Download rate 3.8M/s
# 2021-12-13 12:51:31,634 INFO Welcome to the CDS
# 2021-12-13 12:51:31,635 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:51:31,670 INFO Request is queued
# 2021-12-13 12:51:32,699 INFO Request is running
# 2021-12-13 12:51:39,934 INFO Request is completed
# 2021-12-13 12:51:39,935 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-4e46c916-3d54-45c7-aae2-2114cbe87ecc.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_02_2018.zip (6M)
# 2021-12-13 12:51:41,598 INFO Download rate 3.6M/s
# 2021-12-13 12:51:41,671 INFO Welcome to the CDS
# 2021-12-13 12:51:41,672 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:51:41,715 INFO Request is queued
# 2021-12-13 12:51:42,753 INFO Request is running
# 2021-12-13 12:52:14,146 INFO Request is completed
# 2021-12-13 12:52:14,148 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data7/dataset-cams-europe-air-quality-reanalyses-35848734-5ec1-4fa9-b4c3-2219729ef565.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_03_2018.zip (6.8M)
# 2021-12-13 12:52:16,055 INFO Download rate 3.6M/s
# 2021-12-13 12:52:16,141 INFO Welcome to the CDS
# 2021-12-13 12:52:16,143 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:52:16,202 INFO Request is queued
# 2021-12-13 12:52:17,232 INFO Request is running
# 2021-12-13 12:52:48,704 INFO Request is completed
# 2021-12-13 12:52:48,706 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data0/dataset-cams-europe-air-quality-reanalyses-b9feb759-1202-4846-8bfc-5f749c223b26.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_04_2018.zip (6.6M)
# 2021-12-13 12:52:50,817 INFO Download rate 3.1M/s
# 2021-12-13 12:52:50,898 INFO Welcome to the CDS
# 2021-12-13 12:52:50,900 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:52:50,949 INFO Request is queued
# 2021-12-13 12:52:51,983 INFO Request is running
# 2021-12-13 12:53:04,311 INFO Request is completed
# 2021-12-13 12:53:04,315 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data0/dataset-cams-europe-air-quality-reanalyses-4f852a49-d453-4bb1-9f85-6fc38ddbde38.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_05_2018.zip (6.7M)
# 2021-12-13 12:53:06,243 INFO Download rate 3.5M/s
# 2021-12-13 12:53:06,315 INFO Welcome to the CDS
# 2021-12-13 12:53:06,316 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:53:06,350 INFO Request is queued
# 2021-12-13 12:53:07,384 INFO Request is running
# 2021-12-13 12:53:14,877 INFO Request is completed
# 2021-12-13 12:53:14,878 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data0/dataset-cams-europe-air-quality-reanalyses-4d226555-aa17-4416-84f7-bf536c5788f0.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_06_2018.zip (6.6M)
# 2021-12-13 12:53:16,571 INFO Download rate 3.9M/s
# 2021-12-13 12:53:16,654 INFO Welcome to the CDS
# 2021-12-13 12:53:16,655 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:53:16,693 INFO Request is queued
# 2021-12-13 12:53:17,721 INFO Request is running
# 2021-12-13 12:53:24,958 INFO Request is completed
# 2021-12-13 12:53:24,961 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data0/dataset-cams-europe-air-quality-reanalyses-491ecf30-c382-4dda-b943-c519eea49552.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_07_2018.zip (6.7M)
# 2021-12-13 12:53:27,054 INFO Download rate 3.2M/s
# 2021-12-13 12:53:27,142 INFO Welcome to the CDS
# 2021-12-13 12:53:27,147 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:53:27,198 INFO Request is queued
# 2021-12-13 12:53:28,230 INFO Request is running
# 2021-12-13 12:53:35,465 INFO Request is completed
# 2021-12-13 12:53:35,466 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data0/dataset-cams-europe-air-quality-reanalyses-6829f168-3bf9-4c67-8db4-791c87f53237.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_08_2018.zip (6.7M)
# 2021-12-13 12:53:39,430 INFO Download rate 1.7M/s
# 2021-12-13 12:53:39,498 INFO Welcome to the CDS
# 2021-12-13 12:53:39,499 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:53:39,541 INFO Request is queued
# 2021-12-13 12:53:40,579 INFO Request is running
# 2021-12-13 12:53:53,045 INFO Request is completed
# 2021-12-13 12:53:53,047 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-bac60f0c-06ee-4548-96d9-53e023670383.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_09_2018.zip (6.5M)
# 2021-12-13 12:53:56,535 INFO Download rate 1.9M/s
# 2021-12-13 12:53:56,678 INFO Welcome to the CDS
# 2021-12-13 12:53:56,679 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:53:56,723 INFO Request is queued
# 2021-12-13 12:53:57,766 INFO Request is running
# 2021-12-13 12:54:29,185 INFO Request is completed
# 2021-12-13 12:54:29,189 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data1/dataset-cams-europe-air-quality-reanalyses-79a98ada-ac4f-4a25-9bcd-f04798a6efb0.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_10_2018.zip (6.7M)
# 2021-12-13 12:54:30,865 INFO Download rate 4M/s
# 2021-12-13 12:54:30,940 INFO Welcome to the CDS
# 2021-12-13 12:54:30,941 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:54:30,979 INFO Request is queued
# 2021-12-13 12:54:32,010 INFO Request is running
# 2021-12-13 12:54:44,355 INFO Request is completed
# 2021-12-13 12:54:44,356 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data1/dataset-cams-europe-air-quality-reanalyses-3884356e-d160-4bcb-9fb0-556c82b039fa.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_11_2018.zip (6.5M)
# 2021-12-13 12:54:46,122 INFO Download rate 3.7M/s
# 2021-12-13 12:54:46,190 INFO Welcome to the CDS
# 2021-12-13 12:54:46,191 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:54:46,232 INFO Request is queued
# 2021-12-13 12:54:47,266 INFO Request is running
# 2021-12-13 12:54:59,600 INFO Request is completed
# 2021-12-13 12:54:59,601 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data9/dataset-cams-europe-air-quality-reanalyses-49aa13dd-52c0-4f6f-adb2-464a9e013a6e.zip to F:\Test_2\cams_reanalyses\temp\re_pm2p5_conc_12_2018.zip (6.8M)
# 2021-12-13 12:55:01,722 INFO Download rate 3.2M/s
# 2021-12-13 12:55:01,808 INFO Welcome to the CDS
# 2021-12-13 12:55:01,808 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:55:01,848 INFO Request is queued
# 2021-12-13 12:55:02,881 INFO Request is running
# 2021-12-13 12:55:34,281 INFO Request is completed
# 2021-12-13 12:55:34,286 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data9/dataset-cams-europe-air-quality-reanalyses-4ef671a0-f0c6-4fbf-b344-f6a2b9844856.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_01_2018.zip (6.9M)
# 2021-12-13 12:55:39,242 INFO Download rate 1.4M/s
# 2021-12-13 12:55:39,322 INFO Welcome to the CDS
# 2021-12-13 12:55:39,323 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:55:39,359 INFO Request is queued
# ...
# 2021-12-13 12:57:28,872 INFO Download rate 3M/s
# 2021-12-13 12:57:28,955 INFO Welcome to the CDS
# 2021-12-13 12:57:28,956 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:57:28,994 INFO Request is queued
# 2021-12-13 12:57:30,028 INFO Request is running
# 2021-12-13 12:58:01,460 INFO Request is completed
# 2021-12-13 12:58:01,461 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data9/dataset-cams-europe-air-quality-reanalyses-660bf75c-093a-4144-90e0-1574946e4a3e.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_05_2018.zip (6.8M)
# 2021-12-13 12:58:04,319 INFO Download rate 2.4M/s
# 2021-12-13 12:58:04,396 INFO Welcome to the CDS
# 2021-12-13 12:58:04,397 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:58:04,434 INFO Request is queued
# 2021-12-13 12:58:05,470 INFO Request is running
# 2021-12-13 12:58:36,878 INFO Request is completed
# 2021-12-13 12:58:36,879 INFO Downloading https://download-0003.copernicus-atmosphere.eu/cache-compute-0003/cache/data7/dataset-cams-europe-air-quality-reanalyses-e74bd697-1a6e-47b3-b3c9-4f26a753cae3.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_06_2018.zip (6.6M)
# 2021-12-13 12:58:40,014 INFO Download rate 2.1M/s
# 2021-12-13 12:58:40,092 INFO Welcome to the CDS
# 2021-12-13 12:58:40,093 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:58:40,132 INFO Request is queued
# 2021-12-13 12:58:41,164 INFO Request is running
# 2021-12-13 12:58:48,646 INFO Request is completed
# 2021-12-13 12:58:48,647 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-942c0302-d0fb-4896-a10f-54a3796d2382.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_07_2018.zip (6.9M)
# 2021-12-13 12:58:53,692 INFO Download rate 1.4M/s
# 2021-12-13 12:58:53,841 INFO Welcome to the CDS
# 2021-12-13 12:58:53,842 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:58:53,884 INFO Request is queued
# 2021-12-13 12:58:54,936 INFO Request is running
# 2021-12-13 12:59:02,177 INFO Request is completed
# 2021-12-13 12:59:02,178 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data4/dataset-cams-europe-air-quality-reanalyses-b471f2f8-b4f0-45c7-b8cd-1a3dac9366a6.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_08_2018.zip (6.8M)
# 2021-12-13 12:59:05,012 INFO Download rate 2.4M/s
# 2021-12-13 12:59:05,090 INFO Welcome to the CDS
# 2021-12-13 12:59:05,090 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:59:05,134 INFO Request is queued
# 2021-12-13 12:59:06,168 INFO Request is running
# 2021-12-13 12:59:13,408 INFO Request is completed
# 2021-12-13 12:59:13,409 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data2/dataset-cams-europe-air-quality-reanalyses-bc8127e7-ea91-4c94-b787-7635032338d7.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_09_2018.zip (6.6M)
# 2021-12-13 12:59:16,330 INFO Download rate 2.3M/s
# 2021-12-13 12:59:16,399 INFO Welcome to the CDS
# 2021-12-13 12:59:16,400 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:59:16,438 INFO Request is queued
# 2021-12-13 12:59:17,475 INFO Request is running
# 2021-12-13 12:59:48,865 INFO Request is completed
# 2021-12-13 12:59:48,867 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-ff834a6b-4dd6-4851-8653-8c754bf610f7.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_10_2018.zip (6.8M)
# 2021-12-13 12:59:52,122 INFO Download rate 2.1M/s
# 2021-12-13 12:59:52,454 INFO Welcome to the CDS
# 2021-12-13 12:59:52,456 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 12:59:52,496 INFO Request is queued
# 2021-12-13 12:59:53,529 INFO Request is running
# 2021-12-13 13:00:00,764 INFO Request is completed
# 2021-12-13 13:00:00,765 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-76cc8521-66c9-44e3-88f8-d005ac336d15.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_11_2018.zip (6.7M)
# 2021-12-13 13:00:02,883 INFO Download rate 3.1M/s
# 2021-12-13 13:00:02,957 INFO Welcome to the CDS
# 2021-12-13 13:00:02,958 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:00:02,996 INFO Request is queued
# 2021-12-13 13:00:04,043 INFO Request is running
# 2021-12-13 13:00:16,630 INFO Request is completed
# 2021-12-13 13:00:16,631 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-0c226c43-2624-4b55-85e4-334af3c4e296.zip to F:\Test_2\cams_reanalyses\temp\re_pm10_conc_12_2018.zip (6.9M)
# 2021-12-13 13:00:18,748 INFO Download rate 3.3M/s
# 2021-12-13 13:00:18,828 INFO Welcome to the CDS
# 2021-12-13 13:00:18,829 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:00:18,864 INFO Request is queued
# 2021-12-13 13:00:19,896 INFO Request is running
# 2021-12-13 13:00:32,239 INFO Request is completed
# 2021-12-13 13:00:32,240 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-b9254ee6-99e1-4c03-8ab2-8ac90614b4e0.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_01_2018.zip (6.8M)
# 2021-12-13 13:00:34,071 INFO Download rate 3.7M/s
# 2021-12-13 13:00:34,149 INFO Welcome to the CDS
# 2021-12-13 13:00:34,150 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:00:34,188 INFO Request is queued
# 2021-12-13 13:00:35,217 INFO Request is running
# 2021-12-13 13:00:42,474 INFO Request is completed
# 2021-12-13 13:00:42,475 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-9d6b5c38-6130-4320-9329-d12d542cf9e5.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_02_2018.zip (6.2M)
# 2021-12-13 13:00:44,640 INFO Download rate 2.9M/s
# 2021-12-13 13:00:44,721 INFO Welcome to the CDS
# 2021-12-13 13:00:44,723 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:00:44,767 INFO Request is queued
# 2021-12-13 13:00:45,801 INFO Request is running
# 2021-12-13 13:00:53,039 INFO Request is completed
# 2021-12-13 13:00:53,040 INFO Downloading https://download-0001.copernicus-atmosphere.eu/cache-compute-0001/cache/data5/dataset-cams-europe-air-quality-reanalyses-84768467-e238-42b7-8e68-953b250960da.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_03_2018.zip (6.9M)
# 2021-12-13 13:00:55,285 INFO Download rate 3.1M/s
# 2021-12-13 13:00:55,352 INFO Welcome to the CDS
# 2021-12-13 13:00:55,352 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:00:55,397 INFO Request is queued
# 2021-12-13 13:00:56,684 INFO Request is running
# 2021-12-13 13:01:28,133 INFO Request is completed
# 2021-12-13 13:01:28,135 INFO Downloading https://download-0002.copernicus-atmosphere.eu/cache-compute-0002/cache/data7/dataset-cams-europe-air-quality-reanalyses-b453cf91-d24a-4b42-a19e-a442a48e3c8c.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_04_2018.zip (6.5M)
# 2021-12-13 13:01:30,287 INFO Download rate 3M/s
# 2021-12-13 13:01:30,363 INFO Welcome to the CDS
# 2021-12-13 13:01:30,364 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:01:30,403 INFO Request is queued
# 2021-12-13 13:01:31,433 INFO Request is running
# 2021-12-13 13:02:02,834 INFO Request is completed
# 2021-12-13 13:02:02,835 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-9894f6b2-9b1d-4615-b6a1-71653388c567.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_05_2018.zip (6.7M)
# 2021-12-13 13:02:05,964 INFO Download rate 2.2M/s
# 2021-12-13 13:02:06,032 INFO Welcome to the CDS
# 2021-12-13 13:02:06,033 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:02:06,073 INFO Request is queued
# 2021-12-13 13:02:07,108 INFO Request is running
# 2021-12-13 13:02:19,438 INFO Request is completed
# 2021-12-13 13:02:19,439 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-0200fcbf-0a18-4d24-8571-40cce74a490f.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_06_2018.zip (6.4M)
# 2021-12-13 13:02:21,461 INFO Download rate 3.2M/s
# 2021-12-13 13:02:21,547 INFO Welcome to the CDS
# 2021-12-13 13:02:21,548 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:02:21,585 INFO Request is queued
# 2021-12-13 13:02:22,623 INFO Request is running
# 2021-12-13 13:02:54,274 INFO Request is completed
# 2021-12-13 13:02:54,275 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-665bbdae-a1f4-4ee0-9fc6-4067a90b3d8d.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_07_2018.zip (6.4M)
# 2021-12-13 13:02:58,554 INFO Download rate 1.5M/s
# 2021-12-13 13:02:58,622 INFO Welcome to the CDS
# 2021-12-13 13:02:58,624 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:02:58,661 INFO Request is queued
# 2021-12-13 13:02:59,690 INFO Request is running
# 2021-12-13 13:03:12,010 INFO Request is completed
# 2021-12-13 13:03:12,011 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-5751a5ca-6b80-41a3-a56e-376f33005506.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_08_2018.zip (6.3M)
# 2021-12-13 13:03:14,268 INFO Download rate 2.8M/s
# 2021-12-13 13:03:14,361 INFO Welcome to the CDS
# 2021-12-13 13:03:14,364 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:03:14,410 INFO Request is queued
# 2021-12-13 13:03:15,701 INFO Request is running
# 2021-12-13 13:03:22,934 INFO Request is completed
# 2021-12-13 13:03:22,936 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-4dd273b9-6506-4285-a95f-ea32b7a5f74d.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_09_2018.zip (6.1M)
# 2021-12-13 13:03:24,979 INFO Download rate 3M/s
# 2021-12-13 13:03:25,048 INFO Welcome to the CDS
# 2021-12-13 13:03:25,048 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:03:25,088 INFO Request is queued
# 2021-12-13 13:03:26,121 INFO Request is running
# 2021-12-13 13:03:38,457 INFO Request is completed
# 2021-12-13 13:03:38,458 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-7398c07c-b29e-4991-a51f-d7f38eb4e729.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_10_2018.zip (6.7M)
# 2021-12-13 13:03:43,357 INFO Download rate 1.4M/s
# 2021-12-13 13:03:43,439 INFO Welcome to the CDS
# 2021-12-13 13:03:43,442 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:03:43,493 INFO Request is queued
# 2021-12-13 13:03:44,530 INFO Request is running
# 2021-12-13 13:04:15,926 INFO Request is completed
# 2021-12-13 13:04:15,928 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-0078b80a-6ef8-4a6c-8f15-f71a15e114d3.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_11_2018.zip (6.6M)
# 2021-12-13 13:04:18,245 INFO Download rate 2.9M/s
# 2021-12-13 13:04:18,311 INFO Welcome to the CDS
# 2021-12-13 13:04:18,312 INFO Sending request to https://ads.atmosphere.copernicus.eu/api/v2/resources/cams-europe-air-quality-reanalyses
# 2021-12-13 13:04:18,348 INFO Request is queued
# 2021-12-13 13:04:19,380 INFO Request is running
# 2021-12-13 13:04:51,064 INFO Request is completed
# 2021-12-13 13:04:51,065 INFO Downloading https://download-0000.copernicus-atmosphere.eu/cache-compute-0000/cache/data6/dataset-cams-europe-air-quality-reanalyses-d269f375-b96a-4bf4-b944-8da14fe7813f.zip to F:\Test_2\cams_reanalyses\temp\re_so2_conc_12_2018.zip (6.9M)
# 2021-12-13 13:04:53,413 INFO Download rate 2.9M/s

# %% [markdown]
# ## Combine the monthly datasets per pollutant into a single dataset per pollutant

# %%
for pollutant in POLLUTANTS:
    
    zip_folders = glob.glob(Path(DATA_DIR_CAMS_RE).joinpath(f'temp/re_{POLLUTANTS[pollutant]["CAMS"]}*.zip').as_posix())
                                                            
    if not os.path.exists(Path(DATA_DIR_CAMS_RE).joinpath(f'temp/{POLLUTANTS[pollutant]["CAMS"]}')):
        os.makedirs(Path(DATA_DIR_CAMS_RE).joinpath(f'temp/{POLLUTANTS[pollutant]["CAMS"]}'))
    
    for folder in zip_folders:     
        with zipfile.ZipFile(folder, 'r') as zip_ref:
            zip_ref.extractall(Path(DATA_DIR_CAMS_RE).joinpath(f'temp/{POLLUTANTS[pollutant]["CAMS"]}'))
            
    nc_files = glob.glob(Path(DATA_DIR_CAMS_RE).joinpath(f'temp/{POLLUTANTS[pollutant]["CAMS"]}/*.nc').as_posix())
    
    # open each nc file using xarray
    monthly_datasets = [xr.open_dataset(x) for x in nc_files]

    # combine the data along the time dimension using the xarray combine_nested function 
    ds = xr.combine_nested(monthly_datasets, concat_dim='time', combine_attrs='drop_conflicts')
    
    # rename the variables to match the naming of the CAMS NRT analysis product
    ds = ds.rename(
        {
            'lon':'longitude',
            'lat':'latitude',
            list(ds.data_vars)[0]:POLLUTANTS[pollutant]['CAMS']
        })

    # sort the data based on date
    ds_sorted = ds.sortby('time')
    
    ds_reindexed = ds_sorted.reindex(latitude=list(reversed(ds_sorted.latitude)))
    new_long = np.arange(EXTENTS['IRELAND']['WEST'], EXTENTS['IRELAND']['EAST'] + 0.1, 0.1)
    new_lat = np.arange(EXTENTS['IRELAND']['NORTH'], EXTENTS['IRELAND']['SOUTH'] - 0.1, -0.1)
    ds_interp = ds_reindexed.interp(longitude=list(new_long), latitude=list(new_lat))
    
    # save as a single netcdf file
    ds_interp.to_netcdf(Path(DATA_DIR_CAMS_RE).joinpath(f'{POLLUTANTS[pollutant]["CAMS"]}.nc'))

# %% [markdown]
# ## Upload  to Amazon S3 bucket

# %%
import boto3
from wp4.constants import S3_ACCESS_KEY, S3_SECRET_KEY, S3_ENDPOINT

TARGET_BUCKET = "cams-reanalysis"

s3_client = boto3.client(
    's3',
    aws_access_key_id=S3_ACCESS_KEY,
    aws_secret_access_key=S3_SECRET_KEY,
    endpoint_url=S3_ENDPOINT
)

# %%
# Check if bucket exists and if not create new bucket
existing_bucket_names = [bucket['Name'] for bucket in s3_client.list_buckets()['Buckets']]

if not TARGET_BUCKET in existing_bucket_names:
    print(f'Creating S3 bucket: {TARGET_BUCKET}')
    try:
        s3_client.create_bucket(Bucket=TARGET_BUCKET)
    except:
        raise
    else:
        print(f'Bucket {TARGET_BUCKET} created')
        existing_bucket_names = [bucket['Name'] for bucket in s3_client.list_buckets()['Buckets']]
        print(f'Current buckets: {", ".join(existing_bucket_names)}')

# %%
DATA_DIR = Path(DATA_DIR_CAMS_RE)  # Directory where the file is located
FILE_TYPE = '.nc'  # file extension .nc .tif etc
OVERWRITE_FILE = True  # overwrite the file if already present in the bucket

os.chdir(DATA_DIR)

for pollutant in POLLUTANTS:
    FILE_NAME = POLLUTANTS[pollutant]["CAMS"]
    file_name = f'{FILE_NAME}{FILE_TYPE}'
    out_zip_file = f'{FILE_NAME}.zip'
    out_zip_file_loc = DATA_DIR.joinpath(f'{FILE_NAME}.zip')

    # create zip folder with the file we want to compress 
    zipfile.ZipFile(out_zip_file, mode='w').write(
        file_name,
        compress_type=zipfile.ZIP_DEFLATED
    )

    # list the current contents in the bucket
    bucket_contents = s3_client.list_objects_v2(Bucket=TARGET_BUCKET)

    if "Contents" in bucket_contents.keys():
        bucket_content_names  = [f['Key'] for f in bucket_contents["Contents"]]
    else:
        bucket_content_names  = []


    if out_zip_file in bucket_content_names and not OVERWRITE_FILE:
        # if there is already a file with the same name  in the bucket and we do not want to overwrite
        print(f'{file_name} already present in bucket')
    elif (out_zip_file in bucket_content_names) and OVERWRITE_FILE:
        # if there is already a file with the same name in the bucket and we do want to overwrite
        print(f'{out_zip_file} already present in bucket. Will overwrite this file.')
        print(f'Starting upload of {out_zip_file} to bucket: {TARGET_BUCKET}')
        try:
            s3_client.upload_file(out_zip_file_loc.as_posix(), TARGET_BUCKET, out_zip_file)
        except:
            raise
        else:
            print(f'Upload of {out_zip_file} to bucket: {TARGET_BUCKET} completed')
    else:
        # if there is no file with the same name  in the bucket
        print(f'Starting upload of {out_zip_file} to bucket: {TARGET_BUCKET}')
        try:
            s3_client.upload_file(out_zip_file_loc.as_posix(), TARGET_BUCKET, out_zip_file)
        except:
            raise
        else:
            print(f'Upload of {out_zip_file} to bucket: {TARGET_BUCKET} completed')
            
# remove the zip files

zip_files = glob.glob(DATA_DIR.joinpath('*.zip').as_posix())

for z in zip_files:
    os.remove(z)
# Out:
# co_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of co_conc.zip to bucket: cams-reanalysis
# Upload of co_conc.zip to bucket: cams-reanalysis completed
# o3_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of o3_conc.zip to bucket: cams-reanalysis
# Upload of o3_conc.zip to bucket: cams-reanalysis completed
# no_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of no_conc.zip to bucket: cams-reanalysis
# Upload of no_conc.zip to bucket: cams-reanalysis completed
# no2_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of no2_conc.zip to bucket: cams-reanalysis
# Upload of no2_conc.zip to bucket: cams-reanalysis completed
# pm2p5_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of pm2p5_conc.zip to bucket: cams-reanalysis
# Upload of pm2p5_conc.zip to bucket: cams-reanalysis completed
# pm10_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of pm10_conc.zip to bucket: cams-reanalysis
# Upload of pm10_conc.zip to bucket: cams-reanalysis completed
# so2_conc.zip already present in bucket. Will overwrite this file.
# Starting upload of so2_conc.zip to bucket: cams-reanalysis
# Upload of so2_conc.zip to bucket: cams-reanalysis completed
